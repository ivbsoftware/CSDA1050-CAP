# %% [markdown]
# # Twitter Analysis: Tweets

# %% [markdown]
# By: Jennifer Johnson

# %% [markdown]
# Exploratory Data Analysis
# - Original analysis using all tweets

# %%
# Import packages
import numpy as np
import pandas as pd
import seaborn as sns
import ast, json
import missingno as msno
import geopandas as gpd
from shapely.geometry import Point, Polygon
#import shapefile as shp

from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load the dataset into dataframe
tweets_df = pd.read_csv('D:/development/CSDA1050/playground/twitter_jj/twitter_tweets_new.csv')

# %%
tweets_df.head()
# Out:
#                                               emojis  \
# 0                                    [':red_heart:']
# 1                                                 []
# 2         [':sun_with_face:', ':goat:', ':rainbow:']
# 3                                                 []
# 4  [':fearful_face:', ':fearful_face:', ':flushed...
#
#                                           hashtags                   id  \
# 0                                              NaN  1107369998148788224
# 1                                              NaN  1107370010182324229
# 2  ['kickassvegetables', 'heermancefarmpurveyors']  1107370015932796931
# 3                                       ['Repost']  1107370018730180608
# 4                                              NaN  1107370005883023360
#
#   language  latitude  longitude                  mentions  \
# 0       en       NaN        NaN                       NaN
# 1      und       NaN        NaN  ['Rosalestri', 'Cnyari']
# 2       en   42.0450 -73.862222                       NaN
# 3       en   43.7166 -79.340700       ['MichaelDesbiens']
# 4       ko       NaN        NaN               ['BTS_twt']
#
#                                  place_bbcoordinates place_bbtype  \
# 0  [[[-79.583667, 43.550871], [-79.583667, 43.550...      Polygon
# 1  [[[-80.248423, 43.050553], [-80.248423, 43.470...      Polygon
# 2  [[[-79.76259, 40.477383], [-79.76259, 45.01585...      Polygon
# 3  [[[-79.639319, 43.403221], [-79.639319, 43.855...      Polygon
# 4  [[[-95.155898, 41.676329], [-95.155898, 56.852...      Polygon
#
#    place_country      ...       quoted_text reply_to_status  reply_to_user  \
# 0         Canada      ...               NaN             NaN            NaN
# 1         Canada      ...               NaN    1.107354e+18     Rosalestri
# 2  United States      ...               NaN             NaN            NaN
# 3         Canadá      ...               NaN             NaN            NaN
# 4         Canada      ...               NaN             NaN        BTS_twt
#
#    sensitive                                          sentiment  \
# 0      False  {'neg': 0.0, 'neu': 0.506, 'pos': 0.494, 'comp...
# 1      False  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2      False  {'neg': 0.0, 'neu': 0.68, 'pos': 0.32, 'compou...
# 3      False  {'neg': 0.108, 'neu': 0.676, 'pos': 0.216, 'co...
# 4      False  {'neg': 0.187, 'neu': 0.51, 'pos': 0.304, 'com...
#
#                 source               tweet_date  \
# 0   Twitter for iPhone  2019-03-17 19:55:56.155
# 1  Twitter for Android  2019-03-17 19:55:59.024
# 2            Instagram  2019-03-17 19:56:00.395
# 3            Instagram  2019-03-17 19:56:01.062
# 4   Twitter for iPhone  2019-03-17 19:55:57.999
#
#                                           tweet_text             user_id  \
# 0  Loving the vibes :red_heart:️ https://t.co/X8v...  908049944040361984
# 1                            @Rosalestri @Cnyari Olé            16801721
# 2  Happy Sunday to all and have a wonderful day!!...          1620428460
# 3  #Repost @michaeldesbiens\n・・・\nI have been tol...            53528503
# 4  @BTS_twt 김태형, 밴드에이드? :fearful_face::fearful_fa...  828139192035196928
#
#        user_name
# 0       wikki_87
# 1       njsh2008
# 2  HeermanceFarm
# 3       JimVives
# 4  BangtanBabeXO
#
# [5 rows x 24 columns]

# %%
tweets_df.shape
# Out:
# (184056, 24)

# %%
# check for missing data
msno.matrix(tweets_df)

# %%
# missing correlation matrix
msno.heatmap(tweets_df)

# %%
# changing tweet_date to DateTime column
tweets_df.tweet_date = pd.to_datetime(tweets_df['tweet_date'])

# %%
tweets_df.dtypes
# Out:
# emojis                         object
# hashtags                       object
# id                              int64
# language                       object
# latitude                      float64
# longitude                     float64
# mentions                       object
# place_bbcoordinates            object
# place_bbtype                   object
# place_country                  object
# place_name                     object
# place_type                     object
# quote_status                     bool
# quoted_id                     float64
# quoted_text                    object
# reply_to_status               float64
# reply_to_user                  object
# sensitive                        bool
# sentiment                      object
# source                         object
# tweet_date             datetime64[ns]
# tweet_text                     object
# user_id                         int64
# user_name                      object
# dtype: object

# %%
# Tweets by Date
# See how many tweets come in at a time from streaming
tweets_df['tweet_time'] = tweets_df['tweet_date'].values.astype('datetime64[m]')
tweets_date = tweets_df.groupby('tweet_time').id.agg('count').to_frame('count')#.reset_index()

# %%
tweets_date.head()
# Out:
#                      count
# tweet_time
# 2019-03-17 19:55:00      3
# 2019-03-17 19:56:00     14
# 2019-03-17 19:57:00     15
# 2019-03-17 19:58:00     15
# 2019-03-17 19:59:00     18

# %%
plt.figure(figsize=(12,6), dpi=130)
plt.xlabel('Date/Time of Tweet', fontsize=12)
plt.ylabel('Number of Tweets', fontsize=12)
plt.title('Count of Tweets by Date/Time')
plt.plot(tweets_date)
plt.show()

# %%
tweets_df['tweet_dt']= tweets_df['tweet_date'].dt.normalize()
# Number of Tweets by Day
tweets_day = tweets_df.groupby('tweet_dt')['id'].count()

# %%
tweets_day.head()
# Out:
# tweet_dt
# 2019-03-17     4884
# 2019-03-18    12617
# 2019-03-19    20581
# 2019-03-20    21585
# 2019-03-21     8662
# Name: id, dtype: int64

# %%
ax = sns.countplot(x='tweet_dt', data=tweets_df)
x_dates = tweets_df['tweet_dt'].dt.strftime('%Y-%m-%d').sort_values().unique()
ax.set_xticklabels(labels=x_dates, rotation=45, ha='right')
# Out:
# [Text(0,0,'2019-03-17'),
#  Text(0,0,'2019-03-18'),
#  Text(0,0,'2019-03-19'),
#  Text(0,0,'2019-03-20'),
#  Text(0,0,'2019-03-21'),
#  Text(0,0,'2019-03-23'),
#  Text(0,0,'2019-03-24'),
#  Text(0,0,'2019-03-25'),
#  Text(0,0,'2019-03-26'),
#  Text(0,0,'2019-03-27'),
#  Text(0,0,'2019-03-30'),
#  Text(0,0,'2019-03-31')]

# %%
#tweets_df['tweet_hour']= pd.to_datetime(tweets_df['tweet_date'],format= '%H').dt.time
tweets_df['tweet_hour'] = tweets_df.tweet_date.dt.hour

# %%
# Number of Tweets by Time of Day
tweets_tod = tweets_df.groupby('tweet_hour')['id'].count()

# %%
tweets_tod.head()
# Out:
# tweet_hour
# 0    11403
# 1    12639
# 2    11688
# 3     8939
# 4     5977
# Name: id, dtype: int64

# %%
ax = sns.countplot(x='tweet_hour', data=tweets_df)
#x_dates = tweets_df['tweet_hour'].dt.strftime('%Y-%m-%d').sort_values().unique()
#ax.set_xticklabels(labels=x_dates, rotation=45, ha='right')

# %%
tweets_df['tweet_dow'] = pd.to_datetime(tweets_df['tweet_date']).dt.dayofweek

# %%
# Number of Tweets by Day of Week
tweets_dow = tweets_df.groupby('tweet_dow')['id'].count()

# %%
tweets_dow.head()
# Out:
# tweet_dow
# 0    33466
# 1    43695
# 2    33477
# 3     8662
# 5    28775
# Name: id, dtype: int64

# %%
ax = sns.countplot(x='tweet_dow', data=tweets_df)
#x_dates = tweets_df['tweet_dt'].dt.strftime('%Y-%m-%d').sort_values().unique()
#ax.set_xticklabels(labels=x_dates, rotation=45, ha='right')

# %%
# Number of Tweets by User
tweets_users = tweets_df.groupby('user_name')['id'].count() \
.reset_index(name='count') \
.sort_values(['count'], ascending=False)

# %%
tweets_users.head()
# Out:
#        user_name  count
# 23740    sunowos   1732
# 24576     tofire   1415
# 17134    gleexhy   1382
# 159        511NY   1101
# 14406  biggles14    740

# %%
tweets_df['user_name'].value_counts()[:20].plot(kind='barh')

# %%
tweets_map_df = tweets_df[tweets_df.latitude.notnull()]

# %%
tweets_map_df.head()
# Out:
#                                         emojis  \
# 2   [':sun_with_face:', ':goat:', ':rainbow:']
# 3                                           []
# 6                                           []
# 7                                           []
# 12                                          []
#
#                                              hashtags                   id  \
# 2     ['kickassvegetables', 'heermancefarmpurveyors']  1107370015932796931
# 3                                          ['Repost']  1107370018730180608
# 6   ['torontocontractors', 'renovation', 'interior...  1107370085608538113
# 7                                                 NaN  1107370127874580482
# 12                                          ['pogey']  1107370170467663873
#
#    language   latitude  longitude                        mentions  \
# 2        en  42.045000 -73.862222                             NaN
# 3        en  43.716600 -79.340700             ['MichaelDesbiens']
# 6        en  43.716600 -79.340700                             NaN
# 7        en  43.670060 -79.395480                  ['DinaAlonzi']
# 12       en  43.886417 -78.912659  ['BollocksBar', 'merimacband']
#
#                                   place_bbcoordinates place_bbtype  \
# 2   [[[-79.76259, 40.477383], [-79.76259, 45.01585...      Polygon
# 3   [[[-79.639319, 43.403221], [-79.639319, 43.855...      Polygon
# 6   [[[-79.639319, 43.403221], [-79.639319, 43.855...      Polygon
# 7   [[[-79.639319, 43.403221], [-79.639319, 43.855...      Polygon
# 12  [[[-79.047315, 43.589036], [-79.047315, 44.028...      Polygon
#
#     place_country    ...     \
# 2   United States    ...
# 3          Canadá    ...
# 6          Canada    ...
# 7          Canada    ...
# 12         Canada    ...
#
#                                             sentiment     source  \
# 2   {'neg': 0.0, 'neu': 0.68, 'pos': 0.32, 'compou...  Instagram
# 3   {'neg': 0.108, 'neu': 0.676, 'pos': 0.216, 'co...  Instagram
# 6   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  Instagram
# 7   {'neg': 0.0, 'neu': 0.687, 'pos': 0.313, 'comp...  Instagram
# 12  {'neg': 0.0, 'neu': 0.744, 'pos': 0.256, 'comp...  Instagram
#
#                 tweet_date                                         tweet_text  \
# 2  2019-03-17 19:56:00.395  Happy Sunday to all and have a wonderful day!!...
# 3  2019-03-17 19:56:01.062  #Repost @michaeldesbiens\n・・・\nI have been tol...
# 6  2019-03-17 19:56:17.007  Before and after, big different....\n.\n.\n.\n...
# 7  2019-03-17 19:56:27.084  Simple yet Elegant. . . We love the look of wh...
# 12 2019-03-17 19:56:37.239  Some fine Irish dancing at the @BollocksBar! M...
#
#        user_id      user_name          tweet_time   tweet_dt tweet_hour  \
# 2   1620428460  HeermanceFarm 2019-03-17 19:56:00 2019-03-17         19
# 3     53528503       JimVives 2019-03-17 19:56:00 2019-03-17         19
# 6    349291874        905RENO 2019-03-17 19:56:00 2019-03-17         19
# 7    122201354     DinaAlonzi 2019-03-17 19:56:00 2019-03-17         19
# 12   134236541  gradybrothers 2019-03-17 19:56:00 2019-03-17         19
#
#    tweet_dow
# 2          6
# 3          6
# 6          6
# 7          6
# 12         6
#
# [5 rows x 28 columns]

# %%
tweets_map_df.shape
# Out:
# (25262, 28)

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Jennifer\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import string

# %%
translator = str.maketrans('', '', string.punctuation)

# %%
# Remove punctuation from tweet text
tweets_df['tweet_clean'] = tweets_df['tweet_text'].str.translate(translator)

# %%
# Lower case and split words
tweets_df['tweet_clean'] = tweets_df['tweet_clean'].str.lower().str.split()

# %%
tweets_df.head()
# Out:
#                                               emojis  \
# 0                                    [':red_heart:']
# 1                                                 []
# 2         [':sun_with_face:', ':goat:', ':rainbow:']
# 3                                                 []
# 4  [':fearful_face:', ':fearful_face:', ':flushed...
#
#                                           hashtags                   id  \
# 0                                              NaN  1107369998148788224
# 1                                              NaN  1107370010182324229
# 2  ['kickassvegetables', 'heermancefarmpurveyors']  1107370015932796931
# 3                                       ['Repost']  1107370018730180608
# 4                                              NaN  1107370005883023360
#
#   language  latitude  longitude                  mentions  \
# 0       en       NaN        NaN                       NaN
# 1      und       NaN        NaN  ['Rosalestri', 'Cnyari']
# 2       en   42.0450 -73.862222                       NaN
# 3       en   43.7166 -79.340700       ['MichaelDesbiens']
# 4       ko       NaN        NaN               ['BTS_twt']
#
#                                  place_bbcoordinates place_bbtype  \
# 0  [[[-79.583667, 43.550871], [-79.583667, 43.550...      Polygon
# 1  [[[-80.248423, 43.050553], [-80.248423, 43.470...      Polygon
# 2  [[[-79.76259, 40.477383], [-79.76259, 45.01585...      Polygon
# 3  [[[-79.639319, 43.403221], [-79.639319, 43.855...      Polygon
# 4  [[[-95.155898, 41.676329], [-95.155898, 56.852...      Polygon
#
#    place_country                        ...                          \
# 0         Canada                        ...
# 1         Canada                        ...
# 2  United States                        ...
# 3         Canadá                        ...
# 4         Canada                        ...
#
#                 source              tweet_date  \
# 0   Twitter for iPhone 2019-03-17 19:55:56.155
# 1  Twitter for Android 2019-03-17 19:55:59.024
# 2            Instagram 2019-03-17 19:56:00.395
# 3            Instagram 2019-03-17 19:56:01.062
# 4   Twitter for iPhone 2019-03-17 19:55:57.999
#
#                                           tweet_text             user_id  \
# 0  Loving the vibes :red_heart:️ https://t.co/X8v...  908049944040361984
# 1                            @Rosalestri @Cnyari Olé            16801721
# 2  Happy Sunday to all and have a wonderful day!!...          1620428460
# 3  #Repost @michaeldesbiens\n・・・\nI have been tol...            53528503
# 4  @BTS_twt 김태형, 밴드에이드? :fearful_face::fearful_fa...  828139192035196928
#
#        user_name          tweet_time   tweet_dt  tweet_hour tweet_dow  \
# 0       wikki_87 2019-03-17 19:55:00 2019-03-17          19         6
# 1       njsh2008 2019-03-17 19:55:00 2019-03-17          19         6
# 2  HeermanceFarm 2019-03-17 19:56:00 2019-03-17          19         6
# 3       JimVives 2019-03-17 19:56:00 2019-03-17          19         6
# 4  BangtanBabeXO 2019-03-17 19:55:00 2019-03-17          19         6
#
#                                          tweet_clean
# 0  [loving, the, vibes, redheart️, httpstcox8v0lw...
# 1                          [rosalestri, cnyari, olé]
# 2  [happy, sunday, to, all, and, have, a, wonderf...
# 3  [repost, michaeldesbiens, ・・・, i, have, been, ...
# 4  [btstwt, 김태형, 밴드에이드, fearfulfacefearfulface, w...
#
# [5 rows x 29 columns]

# %%
from nltk.corpus import stopwords
stop_en = stopwords.words("english")

# %%
tweets_df['tweet_clean'] = tweets_df['tweet_clean'].apply(lambda x: [item for item in x if item not in stop_en])

# %%
tweets_df['tweet_clean'] = tweets_df['tweet_clean'].apply(' '.join)

# %%
tweets_df.head()
# Out:
#                                               emojis  \
# 0                                    [':red_heart:']
# 1                                                 []
# 2         [':sun_with_face:', ':goat:', ':rainbow:']
# 3                                                 []
# 4  [':fearful_face:', ':fearful_face:', ':flushed...
#
#                                           hashtags                   id  \
# 0                                              NaN  1107369998148788224
# 1                                              NaN  1107370010182324229
# 2  ['kickassvegetables', 'heermancefarmpurveyors']  1107370015932796931
# 3                                       ['Repost']  1107370018730180608
# 4                                              NaN  1107370005883023360
#
#   language  latitude  longitude                  mentions  \
# 0       en       NaN        NaN                       NaN
# 1      und       NaN        NaN  ['Rosalestri', 'Cnyari']
# 2       en   42.0450 -73.862222                       NaN
# 3       en   43.7166 -79.340700       ['MichaelDesbiens']
# 4       ko       NaN        NaN               ['BTS_twt']
#
#                                  place_bbcoordinates place_bbtype  \
# 0  [[[-79.583667, 43.550871], [-79.583667, 43.550...      Polygon
# 1  [[[-80.248423, 43.050553], [-80.248423, 43.470...      Polygon
# 2  [[[-79.76259, 40.477383], [-79.76259, 45.01585...      Polygon
# 3  [[[-79.639319, 43.403221], [-79.639319, 43.855...      Polygon
# 4  [[[-95.155898, 41.676329], [-95.155898, 56.852...      Polygon
#
#    place_country                        ...                          \
# 0         Canada                        ...
# 1         Canada                        ...
# 2  United States                        ...
# 3         Canadá                        ...
# 4         Canada                        ...
#
#                 source              tweet_date  \
# 0   Twitter for iPhone 2019-03-17 19:55:56.155
# 1  Twitter for Android 2019-03-17 19:55:59.024
# 2            Instagram 2019-03-17 19:56:00.395
# 3            Instagram 2019-03-17 19:56:01.062
# 4   Twitter for iPhone 2019-03-17 19:55:57.999
#
#                                           tweet_text             user_id  \
# 0  Loving the vibes :red_heart:️ https://t.co/X8v...  908049944040361984
# 1                            @Rosalestri @Cnyari Olé            16801721
# 2  Happy Sunday to all and have a wonderful day!!...          1620428460
# 3  #Repost @michaeldesbiens\n・・・\nI have been tol...            53528503
# 4  @BTS_twt 김태형, 밴드에이드? :fearful_face::fearful_fa...  828139192035196928
#
#        user_name          tweet_time   tweet_dt  tweet_hour tweet_dow  \
# 0       wikki_87 2019-03-17 19:55:00 2019-03-17          19         6
# 1       njsh2008 2019-03-17 19:55:00 2019-03-17          19         6
# 2  HeermanceFarm 2019-03-17 19:56:00 2019-03-17          19         6
# 3       JimVives 2019-03-17 19:56:00 2019-03-17          19         6
# 4  BangtanBabeXO 2019-03-17 19:55:00 2019-03-17          19         6
#
#                                          tweet_clean
# 0          loving vibes redheart️ httpstcox8v0lw3wmj
# 1                              rosalestri cnyari olé
# 2  happy sunday wonderful day sunwithfacegoatrain...
# 3  repost michaeldesbiens ・・・ told post many pict...
# 4  btstwt 김태형 밴드에이드 fearfulfacefearfulface cut ho...
#
# [5 rows x 29 columns]

# %%
from wordcloud import WordCloud

# %%
all_words = ' '.join([text for text in tweets_df['tweet_clean']])

# %%
wordcloud = WordCloud(width=800, height=500, random_state=21,
                     max_font_size=110, collocations=False).generate(all_words)

# %%
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
# count of words
words = nltk.tokenize.word_tokenize(all_words)
word_dist = nltk.FreqDist(words)

rslt = pd.DataFrame(word_dist.most_common(30),
                    columns=['Word', 'Frequency'])
rslt.head()
# Out:
#       Word  Frequency
# 0        ’      33207
# 1        s      12195
# 2     like       9674
# 3  toronto       8512
# 4        t       8241

# %%
rslt_words = rslt[rslt['Word'].str.len() > 1]

# %%
rslt_words.head()
# Out:
#       Word  Frequency
# 2     like       9674
# 3  toronto       8512
# 5      amp       7305
# 7      one       6411
# 8      get       6370

# %%
ax = rslt_words.plot.barh(x='Word', y='Frequency')

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Jennifer\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Filter for tweets with hashtags
tweets_hash_df = tweets_df[tweets_df.hashtags.notnull()]

# %%
import ast

# %%
tweets_hash_df['hashtags'] = tweets_hash_df['hashtags'].apply(ast.literal_eval)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
tweets_hash_df['hash'] = tweets_hash_df['hashtags'].apply(', '.join).str.lower()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
hash_words = ', '.join([text for text in tweets_hash_df['hash']])

# %%
wordcloud = WordCloud(width=800, height=500, random_state=21,
                     max_font_size=110, collocations=False).generate(hash_words)

# %%
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
# remove punctuation
tweets_hash_df['hash'] = tweets_hash_df['hash'].str.translate(translator)

a = tweets_hash_df['hash'].str.lower().str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(a)
word_dist = nltk.FreqDist(words)

rslt = pd.DataFrame(word_dist.most_common(20),
                    columns=['Word', 'Frequency'])
rslt.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#            Word  Frequency
# 0       toronto       1572
# 1           ufc        410
# 2     rochester        369
# 3   mississauga        336
# 4  trumpisaliar        313

# %%
ax = rslt.plot.barh(x='Word', y='Frequency')

# %%
# Filter for tweets with emojis
tweets_emoji_df = tweets_df[tweets_df.hashtags.notnull()]

# %%
import ast

# %%
tweets_df['emojis'] = tweets_df['emojis'].apply(ast.literal_eval)

# %%
tweets_df['emo'] = tweets_df['emojis'].apply(', '.join).str.lower()

# %%
emoji_words = ', '.join([text for text in tweets_df['emo']])

# %%
wordcloud = WordCloud(width=800, height=500, random_state=21,
                     max_font_size=110, collocations=False).generate(emoji_words)

# %%
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
# remove punctuation
#tweets_df['emojis'] = tweets_df['emojis'].str.translate(translator)
tweets_df['emo'] = tweets_df['emo'].str.replace(":,", "").str.strip()



a = tweets_df['emo'].str.lower().str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(a)
word_dist = nltk.FreqDist(words)

rslt = pd.DataFrame(word_dist.most_common(20),
                    columns=['Word', 'Frequency'])
rslt = rslt.drop(rslt.index[0])
rslt.head()
# Out:
#                             Word  Frequency
# 1         face_with_tears_of_joy       8609
# 2             loudly_crying_face       3757
# 3                      red_heart       3573
# 4  rolling_on_the_floor_laughing       3241
# 5   smiling_face_with_heart-eyes       2641

# %%
ax = rslt.plot.barh(x='Word', y='Frequency')

# %%
# Filter for tweets with mentions
tweets_mentions_df = tweets_df[tweets_df.mentions.notnull()]

# %%
import ast

# %%
tweets_mentions_df['mentions'] = tweets_mentions_df['mentions'].apply(ast.literal_eval)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
tweets_mentions_df['ment'] = tweets_mentions_df['mentions'].apply(', '.join).str.lower()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
mentions_words = ', '.join([text for text in tweets_mentions_df['ment']])

# %%
wordcloud = WordCloud(width=800, height=500, random_state=21,
                     max_font_size=110, collocations=False).generate(mentions_words)

# %%
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
# remove punctuation
#tweets_hash_df['hash'] = tweets_hash_df['hash'].str.translate(translator)
tweets_mentions_df['ment'] = tweets_mentions_df['ment'].str.replace(",", "").str.strip()

a = tweets_mentions_df['ment'].str.lower().str.cat(sep=' ')
words = nltk.tokenize.word_tokenize(a)
word_dist = nltk.FreqDist(words)

rslt = pd.DataFrame(word_dist.most_common(20),
                    columns=['Word', 'Frequency'])
rslt.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#               Word  Frequency
# 0  realdonaldtrump       1719
# 1    justintrudeau        420
# 2       fordnation        374
# 3              cnn        322
# 4          youtube        288

# %%
ax = rslt.plot.barh(x='Word', y='Frequency')

# %%
# split sentiment into multiple columns (compound, neg, pos, neu)
tweets_df['sentiment'] = tweets_df['sentiment'].apply(lambda x: dict(eval(x)))
tweets_sent = tweets_df['sentiment'].apply(pd.Series)

# %%
tweets_df2 = pd.concat([tweets_df, tweets_sent], axis=1).drop('sentiment', axis=1)

# %%
tweets_df2.head()
# Out:
#                                              emojis  \
# 0                                     [:red_heart:]
# 1                                                []
# 2              [:sun_with_face:, :goat:, :rainbow:]
# 3                                                []
# 4  [:fearful_face:, :fearful_face:, :flushed_face:]
#
#                                           hashtags                   id  \
# 0                                              NaN  1107369998148788224
# 1                                              NaN  1107370010182324229
# 2  ['kickassvegetables', 'heermancefarmpurveyors']  1107370015932796931
# 3                                       ['Repost']  1107370018730180608
# 4                                              NaN  1107370005883023360
#
#   language  latitude  longitude                  mentions  \
# 0       en       NaN        NaN                       NaN
# 1      und       NaN        NaN  ['Rosalestri', 'Cnyari']
# 2       en   42.0450 -73.862222                       NaN
# 3       en   43.7166 -79.340700       ['MichaelDesbiens']
# 4       ko       NaN        NaN               ['BTS_twt']
#
#                                  place_bbcoordinates place_bbtype  \
# 0  [[[-79.583667, 43.550871], [-79.583667, 43.550...      Polygon
# 1  [[[-80.248423, 43.050553], [-80.248423, 43.470...      Polygon
# 2  [[[-79.76259, 40.477383], [-79.76259, 45.01585...      Polygon
# 3  [[[-79.639319, 43.403221], [-79.639319, 43.855...      Polygon
# 4  [[[-95.155898, 41.676329], [-95.155898, 56.852...      Polygon
#
#    place_country  ...            tweet_time   tweet_dt  tweet_hour  tweet_dow  \
# 0         Canada  ...   2019-03-17 19:55:00 2019-03-17          19          6
# 1         Canada  ...   2019-03-17 19:55:00 2019-03-17          19          6
# 2  United States  ...   2019-03-17 19:56:00 2019-03-17          19          6
# 3         Canadá  ...   2019-03-17 19:56:00 2019-03-17          19          6
# 4         Canada  ...   2019-03-17 19:55:00 2019-03-17          19          6
#
#                                          tweet_clean  \
# 0          loving vibes redheart️ httpstcox8v0lw3wmj
# 1                              rosalestri cnyari olé
# 2  happy sunday wonderful day sunwithfacegoatrain...
# 3  repost michaeldesbiens ・・・ told post many pict...
# 4  btstwt 김태형 밴드에이드 fearfulfacefearfulface cut ho...
#
#                                           emo compound    neg    neu    pos
# 0                                 :red_heart:   0.5994  0.000  0.506  0.494
# 1                                               0.0000  0.000  1.000  0.000
# 2              :sun_with_face :goat :rainbow:   0.8395  0.000  0.680  0.320
# 3                                               0.7003  0.108  0.676  0.216
# 4  :fearful_face :fearful_face :flushed_face:   0.5330  0.187  0.510  0.304
#
# [5 rows x 33 columns]
