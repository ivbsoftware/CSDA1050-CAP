# %% [markdown]
# #  GTA News 50 Clusters: generate input for packing

# %% [markdown]
# ## Load 50 cluster dataframe

# %%
import os
from os import listdir
from os.path import isfile, join
import pandas as pd
from collections import Counter

# directories
dir_path = os.getcwd()
#print('Working dir: ' + dir_path)

local_path = dir_path + '\\..\\gta-news\\doc2vec\data\\'
df = pd.read_pickle(local_path+'backup'+'-gta.50'+'.pickle')

# %%
df.head()
# Out:
#         date                                              title  \
# 0 2019-04-20  "this is why we can't have nice things in nyc,...
# 1 2019-04-20  rural book borrowing in peril as libraries sla...
# 2 2019-04-20  "discussing canada's new us-focused cannabis e...
# 3 2019-04-20  serea restaurant slated to open in hotel del c...
# 4 2019-04-20  federal trial of vernon man accused of abducti...
#
#                                                  url  cluster  \
# 0  http://dagblog.com/reader-blogs/why-we-cant-ha...       13
# 1  http://easternontarionetwork.com/2019/04/20/ru...       13
# 2  http://www.benzinga.com/markets/cannabis/19/04...       11
# 3  http://www.coronadonewsca.com/news/coronado_ho...       25
# 4  http://www.courant.com/news/connecticut/hc-new...       46
#
#                                               vector
# 0  [-0.47769657, 0.3672163, 0.23536347, 0.5756423...
# 1  [-0.5722261, -0.26479113, -0.1152498, 0.664171...
# 2  [0.54588157, -0.26139393, -0.18809983, -0.0384...
# 3  [-0.28711024, -0.2106441, -0.61289483, 0.04533...
# 4  [0.062113207, 0.0157832, 0.23044105, 0.4720517...

# %% [markdown]
# ## Add day column

# %%
dfAggr = df[['date','cluster']].groupby(['date','cluster'])\
    .first().sort_values(['date','cluster']).reset_index()

dfCount = df.groupby(['date','cluster'])['cluster']\
    .agg('count').to_frame('count')\
    .sort_values(['date','cluster']).reset_index()['count']

dfAggr['count'] = dfCount
dfAggr.head()
# Out:
#         date  cluster  count
# 0 2019-01-21        0      8
# 1 2019-01-21        1      2
# 2 2019-01-21        2      3
# 3 2019-01-21        3      2
# 4 2019-01-21        4      1

# %%
dfChart = dfAggr #[['date','cluster','count']].sort_values(['date','count'], ascending=[True,True])

#add 'day' column
new_year_day = pd.Timestamp(year=2019, month=1, day=1)
dfChart['day'] = 0
for i, row in dfChart.iterrows():
    dfChart.at[i,'day'] = (row['date'] - new_year_day).days + 1


dfChart.head()
# Out:
#         date  cluster  count  day
# 0 2019-01-21        0      8   21
# 1 2019-01-21        1      2   21
# 2 2019-01-21        2      3   21
# 3 2019-01-21        3      2   21
# 4 2019-01-21        4      1   21

# %% [markdown]
# ## Add missing rows

# %%
num_clusters = 50

missing_rows = []
cur_day = -1
cl_num = 0
len_total = len(dfChart.index)
#print(len_total)
for i, row in dfChart.iterrows():

    # day changed
    if cur_day != row.day:
        cur_day = row.day
        cl_num = 0
    
    # create missing cluster row(s) before row.cluster
    while cl_num != row.cluster:
        d = pd.DataFrame({'date':[row.date],'cluster':[cl_num],'count':[0],'day':[row.day]})
        missing_rows.append(d)
        print ("Created missing row: day:" + str(row.day) + ", cluster:" + str(cl_num))
        cl_num += 1
        if cl_num >= num_clusters:
            break

    # create missing cluster row(s) after row.cluster to end
    if i < len_total:
        if i == len_total -1:
            next_day = -1
        else:
            next_day = dfChart.at[i+1,'day']
        if next_day != cur_day:
            cl_num += 1
            while cl_num < num_clusters:
                d = pd.DataFrame({'date':[row.date],'cluster':[cl_num],'count':[0],'day':[row.day]})
                missing_rows.append(d)
                print ("Created missing row: day:" + str(row.day) + ", cluster:" + str(cl_num))
                cl_num += 1
                if cl_num >= num_clusters:
                    break
            
    cl_num += 1
# Out:
# 3842
# Created missing row: day:21, cluster:8
# Created missing row: day:21, cluster:15
# Created missing row: day:21, cluster:26
# Created missing row: day:21, cluster:43
# Created missing row: day:21, cluster:48
# Created missing row: day:22, cluster:4
# Created missing row: day:22, cluster:6
# Created missing row: day:22, cluster:22
# Created missing row: day:22, cluster:40
# Created missing row: day:22, cluster:43
# Created missing row: day:22, cluster:48
# Created missing row: day:23, cluster:11
# Created missing row: day:23, cluster:19
# Created missing row: day:23, cluster:48
# Created missing row: day:24, cluster:6
# Created missing row: day:24, cluster:11
# Created missing row: day:24, cluster:22
# Created missing row: day:24, cluster:24
# Created missing row: day:24, cluster:26
# Created missing row: day:24, cluster:43
# Created missing row: day:24, cluster:48
# Created missing row: day:25, cluster:2
# Created missing row: day:25, cluster:6
# Created missing row: day:25, cluster:16
# Created missing row: day:25, cluster:22
# Created missing row: day:25, cluster:39
# Created missing row: day:25, cluster:43
# Created missing row: day:25, cluster:48
# Created missing row: day:26, cluster:3
# Created missing row: day:26, cluster:5
# Created missing row: day:26, cluster:6
# Created missing row: day:26, cluster:8
# Created missing row: day:26, cluster:11
# Created missing row: day:26, cluster:16
# Created missing row: day:26, cluster:18
# Created missing row: day:26, cluster:20
# Created missing row: day:26, cluster:22
# Created missing row: day:26, cluster:27
# Created missing row: day:26, cluster:28
# Created missing row: day:26, cluster:41
# Created missing row: day:26, cluster:43
# Created missing row: day:26, cluster:48
# Created missing row: day:27, cluster:0
# Created missing row: day:27, cluster:2
# Created missing row: day:27, cluster:11
# Created missing row: day:27, cluster:18
# Created missing row: day:27, cluster:19
# Created missing row: day:27, cluster:23
# Created missing row: day:27, cluster:28
# Created missing row: day:27, cluster:39
# Created missing row: day:27, cluster:41
# Created missing row: day:27, cluster:43
# Created missing row: day:27, cluster:44
# Created missing row: day:27, cluster:48
# Created missing row: day:27, cluster:49
# Created missing row: day:28, cluster:10
# Created missing row: day:28, cluster:11
# Created missing row: day:28, cluster:22
# Created missing row: day:28, cluster:27
# Created missing row: day:28, cluster:42
# Created missing row: day:28, cluster:48
# Created missing row: day:29, cluster:6
# Created missing row: day:29, cluster:22
# Created missing row: day:29, cluster:48
# Created missing row: day:30, cluster:6
# Created missing row: day:30, cluster:22
# Created missing row: day:30, cluster:24
# Created missing row: day:30, cluster:48
# Created missing row: day:31, cluster:6
# Created missing row: day:31, cluster:19
# Created missing row: day:31, cluster:22
# Created missing row: day:31, cluster:48
# Created missing row: day:32, cluster:6
# Created missing row: day:32, cluster:16
# Created missing row: day:32, cluster:48
# Created missing row: day:33, cluster:0
# Created missing row: day:33, cluster:6
# Created missing row: day:33, cluster:9
# Created missing row: day:33, cluster:10
# Created missing row: day:33, cluster:16
# Created missing row: day:33, cluster:17
# Created missing row: day:33, cluster:21
# Created missing row: day:33, cluster:22
# Created missing row: day:33, cluster:37
# Created missing row: day:33, cluster:48
# Created missing row: day:34, cluster:0
# Created missing row: day:34, cluster:2
# Created missing row: day:34, cluster:6
# Created missing row: day:34, cluster:11
# Created missing row: day:34, cluster:13
# Created missing row: day:34, cluster:14
# Created missing row: day:34, cluster:16
# Created missing row: day:34, cluster:18
# Created missing row: day:34, cluster:20
# Created missing row: day:34, cluster:22
# Created missing row: day:34, cluster:28
# Created missing row: day:34, cluster:30
# Created missing row: day:34, cluster:34
# Created missing row: day:34, cluster:39
# Created missing row: day:34, cluster:45
# Created missing row: day:34, cluster:48
# Created missing row: day:35, cluster:6
# Created missing row: day:35, cluster:14
# Created missing row: day:35, cluster:26
# Created missing row: day:35, cluster:39
# Created missing row: day:35, cluster:42
# Created missing row: day:35, cluster:48
# Created missing row: day:36, cluster:6
# Created missing row: day:36, cluster:22
# Created missing row: day:36, cluster:48
# Created missing row: day:37, cluster:6
# Created missing row: day:37, cluster:19
# Created missing row: day:37, cluster:48
# Created missing row: day:38, cluster:4
# Created missing row: day:38, cluster:34
# Created missing row: day:38, cluster:44
# Created missing row: day:39, cluster:39
# Created missing row: day:40, cluster:3
# Created missing row: day:40, cluster:9
# Created missing row: day:40, cluster:11
# Created missing row: day:40, cluster:12
# Created missing row: day:40, cluster:14
# Created missing row: day:40, cluster:15
# Created missing row: day:40, cluster:18
# Created missing row: day:40, cluster:23
# Created missing row: day:40, cluster:30
# Created missing row: day:40, cluster:35
# Created missing row: day:40, cluster:39
# Created missing row: day:41, cluster:0
# Created missing row: day:41, cluster:1
# Created missing row: day:41, cluster:2
# Created missing row: day:41, cluster:3
# Created missing row: day:41, cluster:5
# Created missing row: day:41, cluster:6
# Created missing row: day:41, cluster:8
# Created missing row: day:41, cluster:9
# Created missing row: day:41, cluster:10
# Created missing row: day:41, cluster:11
# Created missing row: day:41, cluster:14
# Created missing row: day:41, cluster:16
# Created missing row: day:41, cluster:18
# Created missing row: day:41, cluster:25
# Created missing row: day:41, cluster:37
# Created missing row: day:41, cluster:39
# Created missing row: day:41, cluster:41
# Created missing row: day:41, cluster:42
# Created missing row: day:41, cluster:44
# Created missing row: day:41, cluster:45
# Created missing row: day:42, cluster:3
# Created missing row: day:42, cluster:14
# Created missing row: day:42, cluster:22
# Created missing row: day:42, cluster:27
# Created missing row: day:42, cluster:38
# Created missing row: day:43, cluster:16
# Created missing row: day:43, cluster:27
# Created missing row: day:43, cluster:33
# Created missing row: day:43, cluster:49
# Created missing row: day:44, cluster:16
# Created missing row: day:44, cluster:27
# Created missing row: day:44, cluster:33
# Created missing row: day:44, cluster:38
# Created missing row: day:45, cluster:1
# Created missing row: day:45, cluster:3
# Created missing row: day:45, cluster:5
# Created missing row: day:45, cluster:6
# Created missing row: day:45, cluster:17
# Created missing row: day:45, cluster:33
# Created missing row: day:46, cluster:6
# Created missing row: day:46, cluster:26
# Created missing row: day:47, cluster:6
# Created missing row: day:47, cluster:7
# Created missing row: day:47, cluster:8
# Created missing row: day:47, cluster:11
# Created missing row: day:47, cluster:13
# Created missing row: day:47, cluster:14
# Created missing row: day:47, cluster:18
# Created missing row: day:47, cluster:23
# Created missing row: day:47, cluster:41
# Created missing row: day:47, cluster:44
# Created missing row: day:48, cluster:0
# Created missing row: day:48, cluster:2
# Created missing row: day:48, cluster:3
# Created missing row: day:48, cluster:6
# Created missing row: day:48, cluster:11
# Created missing row: day:48, cluster:17
# Created missing row: day:48, cluster:20
# Created missing row: day:48, cluster:25
# Created missing row: day:48, cluster:27
# Created missing row: day:48, cluster:29
# Created missing row: day:48, cluster:30
# Created missing row: day:48, cluster:31
# Created missing row: day:48, cluster:33
# Created missing row: day:48, cluster:34
# Created missing row: day:48, cluster:38
# Created missing row: day:48, cluster:40
# Created missing row: day:48, cluster:44
# Created missing row: day:48, cluster:45
# Created missing row: day:48, cluster:48
# Created missing row: day:49, cluster:6
# Created missing row: day:49, cluster:7
# Created missing row: day:49, cluster:11
# Created missing row: day:49, cluster:17
# Created missing row: day:49, cluster:20
# Created missing row: day:49, cluster:22
# Created missing row: day:49, cluster:32
# Created missing row: day:49, cluster:33
# Created missing row: day:49, cluster:40
# Created missing row: day:49, cluster:43
# Created missing row: day:49, cluster:44
# Created missing row: day:50, cluster:1
# Created missing row: day:50, cluster:8
# Created missing row: day:50, cluster:38
# Created missing row: day:50, cluster:43
# Created missing row: day:51, cluster:6
# Created missing row: day:51, cluster:14
# Created missing row: day:51, cluster:17
# Created missing row: day:51, cluster:23
# Created missing row: day:51, cluster:43
# Created missing row: day:52, cluster:26
# Created missing row: day:52, cluster:44
# Created missing row: day:53, cluster:2
# Created missing row: day:53, cluster:32
# Created missing row: day:54, cluster:9
# Created missing row: day:54, cluster:11
# Created missing row: day:54, cluster:14
# Created missing row: day:54, cluster:15
# Created missing row: day:54, cluster:18
# Created missing row: day:54, cluster:22
# Created missing row: day:54, cluster:25
# Created missing row: day:54, cluster:26
# Created missing row: day:54, cluster:31
# Created missing row: day:54, cluster:42
# Created missing row: day:54, cluster:43
# Created missing row: day:54, cluster:49
# Created missing row: day:55, cluster:0
# Created missing row: day:55, cluster:8
# Created missing row: day:55, cluster:9
# Created missing row: day:55, cluster:10
# Created missing row: day:55, cluster:11
# Created missing row: day:55, cluster:13
# Created missing row: day:55, cluster:16
# Created missing row: day:55, cluster:18
# Created missing row: day:55, cluster:24
# Created missing row: day:55, cluster:25
# Created missing row: day:55, cluster:30
# Created missing row: day:55, cluster:31
# Created missing row: day:55, cluster:33
# Created missing row: day:55, cluster:42
# Created missing row: day:55, cluster:44
# Created missing row: day:55, cluster:48
# Created missing row: day:56, cluster:13
# Created missing row: day:56, cluster:23
# Created missing row: day:56, cluster:26
# Created missing row: day:56, cluster:31
# Created missing row: day:56, cluster:33
# Created missing row: day:56, cluster:43
# Created missing row: day:56, cluster:44
# Created missing row: day:57, cluster:6
# Created missing row: day:57, cluster:26
# Created missing row: day:58, cluster:25
# Created missing row: day:58, cluster:43
# Created missing row: day:58, cluster:44
# Created missing row: day:59, cluster:6
# Created missing row: day:59, cluster:7
# Created missing row: day:59, cluster:15
# Created missing row: day:59, cluster:26
# Created missing row: day:59, cluster:40
# Created missing row: day:60, cluster:15
# Created missing row: day:60, cluster:17
# Created missing row: day:61, cluster:6
# Created missing row: day:61, cluster:10
# Created missing row: day:61, cluster:11
# Created missing row: day:61, cluster:17
# Created missing row: day:61, cluster:23
# Created missing row: day:61, cluster:34
# Created missing row: day:61, cluster:39
# Created missing row: day:61, cluster:41
# Created missing row: day:61, cluster:43
# Created missing row: day:61, cluster:44
# Created missing row: day:62, cluster:0
# Created missing row: day:62, cluster:10
# Created missing row: day:62, cluster:11
# Created missing row: day:62, cluster:12
# Created missing row: day:62, cluster:13
# Created missing row: day:62, cluster:15
# Created missing row: day:62, cluster:17
# Created missing row: day:62, cluster:19
# Created missing row: day:62, cluster:22
# Created missing row: day:62, cluster:27
# Created missing row: day:62, cluster:44
# Created missing row: day:62, cluster:47
# Created missing row: day:62, cluster:49
# Created missing row: day:63, cluster:15
# Created missing row: day:63, cluster:26
# Created missing row: day:64, cluster:6
# Created missing row: day:64, cluster:22
# Created missing row: day:64, cluster:26
# Created missing row: day:64, cluster:35
# Created missing row: day:65, cluster:2
# Created missing row: day:65, cluster:5
# Created missing row: day:65, cluster:6
# Created missing row: day:65, cluster:14
# Created missing row: day:66, cluster:1
# Created missing row: day:67, cluster:2
# Created missing row: day:67, cluster:4
# Created missing row: day:67, cluster:11
# Created missing row: day:67, cluster:25
# Created missing row: day:67, cluster:33
# Created missing row: day:67, cluster:39
# Created missing row: day:67, cluster:43
# Created missing row: day:68, cluster:0
# Created missing row: day:68, cluster:2
# Created missing row: day:68, cluster:6
# Created missing row: day:68, cluster:7
# Created missing row: day:68, cluster:12
# Created missing row: day:68, cluster:15
# Created missing row: day:68, cluster:16
# Created missing row: day:68, cluster:24
# Created missing row: day:68, cluster:31
# Created missing row: day:68, cluster:33
# Created missing row: day:68, cluster:37
# Created missing row: day:68, cluster:39
# Created missing row: day:68, cluster:43
# Created missing row: day:68, cluster:49
# Created missing row: day:69, cluster:1
# Created missing row: day:69, cluster:3
# Created missing row: day:69, cluster:7
# Created missing row: day:69, cluster:11
# Created missing row: day:69, cluster:15
# Created missing row: day:69, cluster:17
# Created missing row: day:69, cluster:26
# Created missing row: day:69, cluster:27
# Created missing row: day:69, cluster:29
# Created missing row: day:69, cluster:33
# Created missing row: day:69, cluster:43
# Created missing row: day:70, cluster:1
# Created missing row: day:70, cluster:2
# Created missing row: day:70, cluster:16
# Created missing row: day:70, cluster:17
# Created missing row: day:70, cluster:26
# Created missing row: day:70, cluster:42
# Created missing row: day:71, cluster:4
# Created missing row: day:71, cluster:22
# Created missing row: day:71, cluster:26
# Created missing row: day:71, cluster:33
# Created missing row: day:71, cluster:42
# Created missing row: day:71, cluster:43
# Created missing row: day:71, cluster:44
# Created missing row: day:72, cluster:16
# Created missing row: day:72, cluster:26
# Created missing row: day:73, cluster:3
# Created missing row: day:73, cluster:24
# Created missing row: day:73, cluster:33
# Created missing row: day:73, cluster:40
# Created missing row: day:73, cluster:43
# Created missing row: day:73, cluster:44
# Created missing row: day:74, cluster:3
# Created missing row: day:74, cluster:15
# Created missing row: day:74, cluster:40
# Created missing row: day:74, cluster:43
# Created missing row: day:75, cluster:3
# Created missing row: day:75, cluster:4
# Created missing row: day:75, cluster:7
# Created missing row: day:75, cluster:9
# Created missing row: day:75, cluster:12
# Created missing row: day:75, cluster:13
# Created missing row: day:75, cluster:15
# Created missing row: day:75, cluster:17
# Created missing row: day:75, cluster:22
# Created missing row: day:75, cluster:23
# Created missing row: day:75, cluster:24
# Created missing row: day:75, cluster:30
# Created missing row: day:75, cluster:31
# Created missing row: day:75, cluster:32
# Created missing row: day:75, cluster:33
# Created missing row: day:75, cluster:34
# Created missing row: day:75, cluster:37
# Created missing row: day:75, cluster:42
# Created missing row: day:76, cluster:0
# Created missing row: day:76, cluster:1
# Created missing row: day:76, cluster:3
# Created missing row: day:76, cluster:13
# Created missing row: day:76, cluster:16
# Created missing row: day:76, cluster:21
# Created missing row: day:76, cluster:22
# Created missing row: day:76, cluster:24
# Created missing row: day:76, cluster:27
# Created missing row: day:76, cluster:33
# Created missing row: day:76, cluster:39
# Created missing row: day:76, cluster:43
# Created missing row: day:76, cluster:47
# Created missing row: day:76, cluster:48
# Created missing row: day:77, cluster:3
# Created missing row: day:77, cluster:5
# Created missing row: day:77, cluster:6
# Created missing row: day:77, cluster:16
# Created missing row: day:77, cluster:33
# Created missing row: day:77, cluster:39
# Created missing row: day:77, cluster:42
# Created missing row: day:77, cluster:43
# Created missing row: day:77, cluster:44
# Created missing row: day:78, cluster:33
# Created missing row: day:78, cluster:43
# Created missing row: day:78, cluster:48
# Created missing row: day:79, cluster:6
# Created missing row: day:79, cluster:9
# Created missing row: day:79, cluster:16
# Created missing row: day:79, cluster:24
# Created missing row: day:79, cluster:31
# Created missing row: day:79, cluster:33
# Created missing row: day:79, cluster:36
# Created missing row: day:79, cluster:37
# Created missing row: day:79, cluster:39
# Created missing row: day:79, cluster:43
# Created missing row: day:80, cluster:2
# Created missing row: day:80, cluster:16
# Created missing row: day:80, cluster:33
# Created missing row: day:81, cluster:2
# Created missing row: day:81, cluster:9
# Created missing row: day:81, cluster:15
# Created missing row: day:81, cluster:33
# Created missing row: day:81, cluster:39
# Created missing row: day:82, cluster:2
# Created missing row: day:82, cluster:9
# Created missing row: day:82, cluster:13
# Created missing row: day:82, cluster:14
# Created missing row: day:82, cluster:22
# Created missing row: day:82, cluster:25
# Created missing row: day:82, cluster:32
# Created missing row: day:82, cluster:33
# Created missing row: day:82, cluster:36
# Created missing row: day:82, cluster:41
# Created missing row: day:83, cluster:0
# Created missing row: day:83, cluster:2
# Created missing row: day:83, cluster:11
# Created missing row: day:83, cluster:13
# Created missing row: day:83, cluster:15
# Created missing row: day:83, cluster:16
# Created missing row: day:83, cluster:22
# Created missing row: day:83, cluster:31
# Created missing row: day:83, cluster:33
# Created missing row: day:83, cluster:42
# Created missing row: day:83, cluster:49
# Created missing row: day:84, cluster:2
# Created missing row: day:84, cluster:6
# Created missing row: day:84, cluster:15
# Created missing row: day:84, cluster:22
# Created missing row: day:84, cluster:23
# Created missing row: day:85, cluster:3
# Created missing row: day:85, cluster:15
# Created missing row: day:85, cluster:16
# Created missing row: day:85, cluster:22
# Created missing row: day:86, cluster:2
# Created missing row: day:86, cluster:6
# Created missing row: day:86, cluster:16
# Created missing row: day:86, cluster:18
# Created missing row: day:86, cluster:26
# Created missing row: day:86, cluster:37
# Created missing row: day:86, cluster:42
# Created missing row: day:86, cluster:43
# Created missing row: day:87, cluster:2
# Created missing row: day:87, cluster:3
# Created missing row: day:87, cluster:6
# Created missing row: day:87, cluster:22
# Created missing row: day:87, cluster:26
# Created missing row: day:87, cluster:27
# Created missing row: day:87, cluster:43
# Created missing row: day:87, cluster:49
# Created missing row: day:88, cluster:2
# Created missing row: day:88, cluster:16
# Created missing row: day:88, cluster:22
# Created missing row: day:88, cluster:31
# Created missing row: day:89, cluster:1
# Created missing row: day:89, cluster:2
# Created missing row: day:89, cluster:4
# Created missing row: day:89, cluster:6
# Created missing row: day:89, cluster:8
# Created missing row: day:89, cluster:9
# Created missing row: day:89, cluster:12
# Created missing row: day:89, cluster:16
# Created missing row: day:89, cluster:26
# Created missing row: day:89, cluster:27
# Created missing row: day:89, cluster:37
# Created missing row: day:89, cluster:43
# Created missing row: day:89, cluster:44
# Created missing row: day:90, cluster:0
# Created missing row: day:90, cluster:5
# Created missing row: day:90, cluster:7
# Created missing row: day:90, cluster:16
# Created missing row: day:90, cluster:20
# Created missing row: day:90, cluster:21
# Created missing row: day:90, cluster:22
# Created missing row: day:90, cluster:23
# Created missing row: day:90, cluster:27
# Created missing row: day:90, cluster:29
# Created missing row: day:90, cluster:30
# Created missing row: day:90, cluster:33
# Created missing row: day:90, cluster:35
# Created missing row: day:90, cluster:39
# Created missing row: day:90, cluster:40
# Created missing row: day:90, cluster:44
# Created missing row: day:90, cluster:49
# Created missing row: day:91, cluster:6
# Created missing row: day:91, cluster:11
# Created missing row: day:91, cluster:12
# Created missing row: day:91, cluster:15
# Created missing row: day:91, cluster:18
# Created missing row: day:91, cluster:19
# Created missing row: day:91, cluster:20
# Created missing row: day:91, cluster:22
# Created missing row: day:91, cluster:32
# Created missing row: day:91, cluster:33
# Created missing row: day:91, cluster:37
# Created missing row: day:91, cluster:38
# Created missing row: day:91, cluster:41
# Created missing row: day:91, cluster:43
# Created missing row: day:91, cluster:44
# Created missing row: day:91, cluster:49
# Created missing row: day:92, cluster:25
# Created missing row: day:92, cluster:33
# Created missing row: day:93, cluster:3
# Created missing row: day:93, cluster:4
# Created missing row: day:93, cluster:22
# Created missing row: day:93, cluster:24
# Created missing row: day:94, cluster:1
# Created missing row: day:94, cluster:2
# Created missing row: day:94, cluster:8
# Created missing row: day:94, cluster:22
# Created missing row: day:94, cluster:43
# Created missing row: day:95, cluster:2
# Created missing row: day:95, cluster:22
# Created missing row: day:95, cluster:42
# Created missing row: day:95, cluster:43
# Created missing row: day:96, cluster:2
# Created missing row: day:96, cluster:11
# Created missing row: day:96, cluster:15
# Created missing row: day:96, cluster:16
# Created missing row: day:96, cluster:22
# Created missing row: day:96, cluster:27
# Created missing row: day:96, cluster:29
# Created missing row: day:96, cluster:34
# Created missing row: day:96, cluster:35
# Created missing row: day:96, cluster:37
# Created missing row: day:96, cluster:42
# Created missing row: day:96, cluster:43
# Created missing row: day:96, cluster:44
# Created missing row: day:97, cluster:2
# Created missing row: day:97, cluster:7
# Created missing row: day:97, cluster:9
# Created missing row: day:97, cluster:10
# Created missing row: day:97, cluster:11
# Created missing row: day:97, cluster:14
# Created missing row: day:97, cluster:15
# Created missing row: day:97, cluster:16
# Created missing row: day:97, cluster:18
# Created missing row: day:97, cluster:22
# Created missing row: day:97, cluster:23
# Created missing row: day:97, cluster:27
# Created missing row: day:97, cluster:31
# Created missing row: day:97, cluster:33
# Created missing row: day:97, cluster:34
# Created missing row: day:97, cluster:35
# Created missing row: day:97, cluster:41
# Created missing row: day:97, cluster:44
# Created missing row: day:97, cluster:47
# Created missing row: day:98, cluster:6
# Created missing row: day:98, cluster:16
# Created missing row: day:98, cluster:22
# Created missing row: day:98, cluster:33
# Created missing row: day:98, cluster:42
# Created missing row: day:98, cluster:47
# Created missing row: day:99, cluster:2
# Created missing row: day:99, cluster:6
# Created missing row: day:99, cluster:22
# Created missing row: day:99, cluster:38
# Created missing row: day:99, cluster:43
# Created missing row: day:100, cluster:1
# Created missing row: day:100, cluster:22
# Created missing row: day:100, cluster:42
# Created missing row: day:100, cluster:43
# Created missing row: day:101, cluster:23
# Created missing row: day:101, cluster:43
# Created missing row: day:102, cluster:6
# Created missing row: day:102, cluster:15
# Created missing row: day:102, cluster:17
# Created missing row: day:102, cluster:42
# Created missing row: day:102, cluster:43
# Created missing row: day:102, cluster:48
# Created missing row: day:103, cluster:2
# Created missing row: day:103, cluster:6
# Created missing row: day:103, cluster:7
# Created missing row: day:103, cluster:9
# Created missing row: day:103, cluster:15
# Created missing row: day:103, cluster:16
# Created missing row: day:103, cluster:27
# Created missing row: day:103, cluster:31
# Created missing row: day:103, cluster:33
# Created missing row: day:103, cluster:36
# Created missing row: day:103, cluster:39
# Created missing row: day:103, cluster:40
# Created missing row: day:103, cluster:42
# Created missing row: day:104, cluster:0
# Created missing row: day:104, cluster:1
# Created missing row: day:104, cluster:6
# Created missing row: day:104, cluster:18
# Created missing row: day:104, cluster:19
# Created missing row: day:104, cluster:21
# Created missing row: day:104, cluster:22
# Created missing row: day:104, cluster:23
# Created missing row: day:104, cluster:28
# Created missing row: day:104, cluster:33
# Created missing row: day:104, cluster:40
# Created missing row: day:104, cluster:42
# Created missing row: day:104, cluster:43
# Created missing row: day:104, cluster:44
# Created missing row: day:104, cluster:45
# Created missing row: day:104, cluster:47
# Created missing row: day:104, cluster:48
# Created missing row: day:105, cluster:6
# Created missing row: day:105, cluster:16
# Created missing row: day:105, cluster:22
# Created missing row: day:105, cluster:24
# Created missing row: day:106, cluster:22
# Created missing row: day:107, cluster:2
# Created missing row: day:107, cluster:22
# Created missing row: day:107, cluster:43
# Created missing row: day:108, cluster:8
# Created missing row: day:108, cluster:15
# Created missing row: day:108, cluster:22
# Created missing row: day:108, cluster:33
# Created missing row: day:108, cluster:48
# Created missing row: day:109, cluster:4
# Created missing row: day:109, cluster:15
# Created missing row: day:109, cluster:22
# Created missing row: day:109, cluster:24
# Created missing row: day:109, cluster:42
# Created missing row: day:109, cluster:43
# Created missing row: day:109, cluster:44
# Created missing row: day:110, cluster:1
# Created missing row: day:110, cluster:2
# Created missing row: day:110, cluster:6
# Created missing row: day:110, cluster:7
# Created missing row: day:110, cluster:9
# Created missing row: day:110, cluster:12
# Created missing row: day:110, cluster:15
# Created missing row: day:110, cluster:16
# Created missing row: day:110, cluster:18
# Created missing row: day:110, cluster:22
# Created missing row: day:110, cluster:29
# Created missing row: day:110, cluster:31
# Created missing row: day:110, cluster:33
# Created missing row: day:110, cluster:35
# Created missing row: day:110, cluster:36
# Created missing row: day:110, cluster:40
# Created missing row: day:110, cluster:42
# Created missing row: day:110, cluster:47
# Created missing row: day:110, cluster:48
# Created missing row: day:110, cluster:49

# %%
dfChart2 = dfChart.append(missing_rows, sort=True)
dfChart2 = dfChart2.sort_values(['day','count','cluster'], ascending=[True,False,True])
dfChart2 = dfChart2.reset_index(drop=True)

dfChart2[dfChart2.day == 110].head()
# Out:
#       cluster  count       date  day
# 4450       46     11 2019-04-20  110
# 4451        3      7 2019-04-20  110
# 4452       13      5 2019-04-20  110
# 4453       14      5 2019-04-20  110
# 4454       17      4 2019-04-20  110

# %% [markdown]
# ## Save CSV

# %%
dfChart2[['day','date','cluster','count']].to_csv("packing_input.csv", index=False)
