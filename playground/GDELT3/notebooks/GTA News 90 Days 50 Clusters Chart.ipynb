# %% [markdown]
# #  GTA News 50 Clusters Chart

# %% [markdown]
# ## Load 50 cluster dataframe

# %%
import os
from os import listdir
from os.path import isfile, join
import pandas as pd
from collections import Counter

# directories
dir_path = os.getcwd()
#print('Working dir: ' + dir_path)

local_path = dir_path + '\\..\\gta-news\\doc2vec\data\\'
df = pd.read_pickle(local_path+'backup'+'-gta.50'+'.pickle')

# %%
df.head()
# Out:
#         date                                              title  \
# 0 2019-04-20  "this is why we can't have nice things in nyc,...
# 1 2019-04-20  rural book borrowing in peril as libraries sla...
# 2 2019-04-20  "discussing canada's new us-focused cannabis e...
# 3 2019-04-20  serea restaurant slated to open in hotel del c...
# 4 2019-04-20  federal trial of vernon man accused of abducti...
#
#                                                  url  cluster
# 0  http://dagblog.com/reader-blogs/why-we-cant-ha...       20
# 1  http://easternontarionetwork.com/2019/04/20/ru...       12
# 2  http://www.benzinga.com/markets/cannabis/19/04...        5
# 3  http://www.coronadonewsca.com/news/coronado_ho...       31
# 4  http://www.courant.com/news/connecticut/hc-new...       46

# %% [markdown]
# ## Get cluster descriptions from titles

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../gta-news/doc2vec'))
if module_path not in sys.path:
    sys.path.append(module_path)

import d2v_utils
skip_terms =['toronto','canada','canadian','ontario']
cluster_descr = []
clusters = df.groupby(['cluster'])['title']
for cluster, titles in clusters:
    #print("\nCluster: ", cluster)
    filtered_words = []
    for title in titles:
        t = title[0:-4]
        #print(">>>", t)
        tokens = d2v_utils.prepare_text_for_lda(t)
        tokens = [word for word in tokens if word not in skip_terms and not word.isdigit()]
        #print("  >", tokens)
        filtered_words = filtered_words + tokens
    count = Counter(filtered_words)
    current_clust_descr = count.most_common()[:10] 
    cluster_descr.append(current_clust_descr)

# %%
print(cluster_descr[0][0:5])
print(cluster_descr[1][0:5])
print(cluster_descr[2][0:5])
print(cluster_descr[3][0:5])
print(cluster_descr[4][0:5])
print(cluster_descr[5][0:5])
# Out:
# [('announce', 132), ('cannabis', 45), ('board', 29), ('update', 23), ('technology', 23)]
# [('refugee', 52), ('asylum', 47), ('snowden', 46), ('shelter', 44), ('grant', 30)]
# [('announce', 68), ('project', 39), ('resource', 36), ('result', 27), ('mining', 21)]
# [('weather', 23), ('winter', 22), ('storm', 16), ('school', 11), ('continue', 10)]
# [('court', 42), ('decision', 18), ('appeal', 17), ('supreme', 16), ('government', 15)]
# [('cannabis', 156), ('company', 37), ('store', 24), ('rogen', 22), ('growth', 20)]

# %%
decriptions = []
for row in cluster_descr:
    d=[]
    for token in row:
        d.append(token[0])
    decriptions.append(d)

data = df
description = []
for i, row in df.iterrows():
    description.append(decriptions[row['cluster']])

data['description'] = description

# %% [markdown]
# ## Prepare the dataset

# %%
df.head()
# Out:
#         date                                              title  \
# 0 2019-04-20  "this is why we can't have nice things in nyc,...
# 1 2019-04-20  rural book borrowing in peril as libraries sla...
# 2 2019-04-20  "discussing canada's new us-focused cannabis e...
# 3 2019-04-20  serea restaurant slated to open in hotel del c...
# 4 2019-04-20  federal trial of vernon man accused of abducti...
#
#                                                  url  cluster  \
# 0  http://dagblog.com/reader-blogs/why-we-cant-ha...       20
# 1  http://easternontarionetwork.com/2019/04/20/ru...       12
# 2  http://www.benzinga.com/markets/cannabis/19/04...        5
# 3  http://www.coronadonewsca.com/news/coronado_ho...       31
# 4  http://www.courant.com/news/connecticut/hc-new...       46
#
#                                          description
# 0  [transit, sidewalk, project, subway, plan, sma...
# 1  [health, government, budget, funding, public, ...
# 2  [cannabis, company, store, rogen, growth, mari...
# 3  [restaurant, store, first, announce, location,...
# 4  [police, charge, arrest, assault, woman, suspe...

# %%
# need dfAggr:
# date, cluster, count, description, x, y
dfAggr = df[['date','cluster','description']].groupby(['date','cluster'])\
    .first().sort_values(['date','cluster']).reset_index()

dfCount = df.groupby(['date','cluster'])['cluster']\
    .agg('count').to_frame('count')\
    .sort_values(['date','cluster']).reset_index()['count']

dfAggr['count'] = dfCount

# create topic string
topics = []
for i, row in dfAggr.iterrows():
    topics.append(', '.join(row['description'][0:2]))
dfAggr['topic'] = topics


# temporary RANDOM
import random
import numpy as np
random.seed(11)
dfAggr['x'] = 0.0
dfAggr['y'] = 0.0
sampl_x = np.random.uniform(low=0.0, high=50.0, size=(50,))
sampl_y = np.random.uniform(low=0.0, high=50.0, size=(50,))
for i, row in dfAggr.iterrows():
    dfAggr.at[i,'x'] = sampl_x[row.cluster]
    dfAggr.at[i,'y'] = sampl_y[row.cluster]

dfAggr.head(10)
# Out:
#         date  cluster                                        description  \
# 0 2019-01-21        0  [announce, cannabis, board, update, technology...
# 1 2019-01-21        1  [refugee, asylum, snowden, shelter, grant, wom...
# 2 2019-01-21        2  [announce, project, resource, result, mining, ...
# 3 2019-01-21        3  [weather, winter, storm, school, continue, swe...
# 4 2019-01-21        4  [court, decision, appeal, supreme, government,...
# 5 2019-01-21        5  [cannabis, company, store, rogen, growth, mari...
# 6 2019-01-21        6  [woman, survivor, family, cancer, holocaust, f...
# 7 2019-01-21        8  [research, company, university, better, drivin...
# 8 2019-01-21        9  [study, award, could, researcher, science, sci...
# 9 2019-01-21       10  [crash, ethiopian, plane, airline, family, vic...
#
#    count               topic          x          y
# 0      5  announce, cannabis  40.770015   6.339483
# 1      2     refugee, asylum   1.262558  35.072014
# 2      4   announce, project   9.427444  48.594354
# 3      4     weather, winter   0.647707  19.914938
# 4      5     court, decision   6.005125   5.644537
# 5      4   cannabis, company  22.003997  25.330922
# 6      2     woman, survivor  28.415228  25.735026
# 7      2   research, company   1.490165  25.980810
# 8      3        study, award  28.691782  46.102821
# 9      2    crash, ethiopian  46.349804  18.963932

# %% [markdown]
# ## Cleaning dataset

# %%
dfChart = dfAggr.sort_values(['date','count'], ascending=[True,False]).groupby('date').head(20)
dfChart = dfChart[dfChart['count'] > 2]
dfChart = dfChart.reset_index()

#date not working in chart
new_year_day = pd.Timestamp(year=2019, month=1, day=1)
dfChart['day'] = 0
for i, row in dfChart.iterrows():
    dfChart.at[i,'day'] = (row['date'] - new_year_day).days + 1

dfChart.head()
# Out:
#    index       date  cluster  \
# 0     27 2019-01-21       30
# 1     40 2019-01-21       45
# 2     13 2019-01-21       14
# 3     24 2019-01-21       27
# 4     11 2019-01-21       12
#
#                                          description  count  \
# 0  [trudeau, liberal, carbon, climate, government...      8
# 1  [founder, deciem, brandon, truaxe, reporter, p...      8
# 2  [announce, business, launch, digital, award, m...      7
# 3  [barrick, newmont, dollar, company, investor, ...      7
# 4  [health, government, budget, funding, public, ...      6
#
#                 topic          x          y  day
# 0    trudeau, liberal  33.169944  49.660420   21
# 1     founder, deciem  28.522375   3.542355   21
# 2  announce, business  35.549840  12.777205   21
# 3    barrick, newmont  40.561493  28.097267   21
# 4  health, government   6.301551  45.360687   21

# %% [markdown]
# ## TODO: Project clustering to 2D using PCA

# %%
#from sklearn.decomposition import PCA
#pca = PCA(n_components=2)
#principalComponents = pca.fit_transform(x)
#principalDf = pd.DataFrame(data = principalComponents
#             , columns = ['principal component 1', 'principal component 2'])

# %% [markdown]
# ## Plot

# %%
import plotly_express as px
px.scatter(dfChart, x="x", y="y", animation_frame="day", animation_group="topic",
           size="count", color="topic", hover_name="topic",
           size_max=150, range_x=[-5,65], range_y=[-5,65])
# Out:
# <div>
#
#
#             <div id="d8e8948e-d4f1-4d16-9620-98729487c7ac" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d8e8948e-d4f1-4d16-9620-98729487c7ac")) {
#                     Plotly.newPlot(
#                         'd8e8948e-d4f1-4d16-9620-98729487c7ac',
#                         [{"hovertemplate": "<b>%{hovertext}</b><br><br>day=22<br>topic=health, government<br>x=%{x}<br>y=%{y}<br>count=%{marker.size}<extra></extra>", "hovertext": ["health, government"], "ids": ["health, government"], "legendgroup": "topic=health, government", "marker": {"color": "#636efa", "size": [14], "sizemode": "area", "sizeref": 0.0033333333333333335, "symbol": "circle"}, "mode": "markers", "name": "topic=health, government", "showlegend": true, "type": "scatter", "uid": "ed1f05fa-be62-41a8-99d6-a0c5fd436426", "x": [6.301551152844026], "xaxis": "x", "y": [45.36068657122981], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>day=22<br>topic=barrick, newmont<br>x=%{x}<br>y=%{y}<br>count=%{marker.size}<extra></extra>", "hovertext": ["barrick, newmont"], "ids": ["barrick, newmont"], "legendgroup": "topic=barrick, newmont", "marker": {"color": "#EF553B", "size": [7], "sizemode": "area", "sizeref": 0.0033333333333333335, "symbol": "circle"}, "mode": "markers", "name": "topic=barrick, newmont", "showlegend": true, "type": "scatter", "uid": "4bfb6525-118d-48a0-8105-511fef1c48cc", "x": [40.56149345429784], "xaxis": "x", "y": [28.097267069634707], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>day=22<br>topic=resident, downtown<br>x=%{x}<br>y=%{y}<br>count=%{marker.size}<extra></extra>", "hovertext": ["resident, downtown"], "ids": ["resident, downtown"], "legendgroup": "topic=resident, downtown", "marker": {"color": "#00cc96", "size": [5], "sizemode": "area", "sizeref": 0.0033333333333333335, "symbol": "circle"}, "mode": "markers", "name": "topic=resident, downtown", "showlegend": true, "type": "scatter", "uid": "8a820d9f-d666-4077-a82a-d523b7786ce3", "x": [6.447626156973957], "xaxis": "x", "y": [36.63028450309921], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>day=22<br>topic=police, shooting<br>x=%{x}<br>y=%{y}<br>count=%{marker.size}<extra></extra>", "hovertext": ["police, shooting"], "ids": ["police, shooting"], "legendgroup": "topic=police, shooting", "marker": {"color": "#ab63fa", "size": [7], "sizemode": "area", "sizeref": 0.0033333333333333335, "symbol": "circle"}, "mode": "markers", "name": "topic=police, shooting", "showlegend": true, "type": "scatter", "uid": "372e3444-bd7b-43a6-b069-6583d03e1a49", "x": [6.447421516348218], "xaxis": "x", "y": [21.76131129578216], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>day=22<br>topic=restaurant, store<br>x=%{x}<br>y=%{y}<br>count=%{marker.size}<extra></extra>", "hovertext": ["restaurant, store"], "ids": ["restaurant, store"], "legendgroup": "topic=restaurant, store", "marker": {"color": "#19d3f3", "size": [6], "sizemode": "area", "sizeref": 0.0033333333333333335, "symbol": "circle"}, "mode": "markers", "name": "topic=restaurant, store", "showlegend": true, "type": "scatter", "uid": "fd0dae2b-f9e7-46e7-91b3-aa8b9857dbe0", "x": [45.52247711512536], "xaxis": "x", "y": [10.368655130351662], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>day=22<br>topic=oscar, netflix<br>x=%{x}<br>y=%{y}<br>count=%{marker.size}<extra></extra>", "hovertext": ["oscar, netflix"], "ids": ["oscar, netflix"], "legendgroup": "topic=oscar, netflix", "marker": {"color": "#e763fa", "size": [11], "sizemode": "area", "sizeref": 0.0033333333333333335, "symbol": "circle"}, "mode": "markers", "name": "topic=oscar, netflix", "showlegend": true, "type": "scatter", "uid": "4bb614da-f46d-4510-8c5e-788f3e6dfa69", "x": [7.474353870293155], "xaxis": "x", "y": [16.445351958906674], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>day=22<br>topic=research, company<br>x=%{x}<br>y=%{y}<br>count=%{marker.size}<extra></extra>", "hovertext": ["research, company"], "ids": ["research, company"], "legendgroup": "topic=research, company", "marker": {"color": "#fecb52", "size": [4], "sizemode": "area", "sizeref": 0.0033333333333333335, "symbol": "circle"}, "mode": "markers", "name": "topic=research, company", "showlegend": true, "type": " ...
